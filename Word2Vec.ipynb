# %%
import tensorflow as tf
import math
from random import randint
import numpy as np
from nltk.corpus import stopwords
import string

# %%
chat = [
    [
    "king is husband of queen",
    "queen is wife of king",
    "king is male",
    "queen is female",
    "king marry queen"
    ]
]
valid_words = ["king","queen"]

# %%
words = set()
sentences = []

stops = stopwords.words('english')

for message in chat: 
    for sentence in message:
        
        # Lower case
        texts = sentence.lower().split(" ")

        # Remove punctuation
        texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]

        # Remove numbers
        texts = [''.join(c for c in x if c not in '0123456789') for x in texts]

        # Remove stopwords
        texts = [' '.join([word for word in x.split() if word not in stops]) for x in texts]
    
        texts = [x for x in texts if x]
        
        sentences.append(sentence)
        
        for word in texts:
            words.add(word)

words = list(words)
word_dictionary_rev = {k:v for k, v in enumerate(words)}

# %%
wordVectorDim = 3
vocabSize = len(words)
batchSize = 4
numNegativeSample = int(batchSize/2)
windowSize = 3
learning_rate = 0.1
iterations = 100000
debug_iterations = 20000
debug_iterations = 200

# %%
nceWeights = tf.Variable(tf.random.truncated_normal([vocabSize, wordVectorDim], 
                                             stddev=1.0 / math.sqrt(wordVectorDim)))
nceBiases = tf.Variable(tf.zeros([vocabSize]))

# %%
train_inputs = tf.placeholder(tf.int32, shape=[batchSize])
train_outputs = tf.placeholder(tf.int32, shape=[batchSize, 1])

# %%
embeddings = tf.Variable(tf.random.uniform(
    [vocabSize, wordVectorDim],
    minval=-1.0,
    maxval=1.0))
embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# %%
loss = tf.reduce_mean(
  tf.nn.nce_loss(weights=nceWeights,
                 biases=nceBiases,
                 labels=train_outputs,
                 inputs=embed,
                 num_sampled=numNegativeSample,
                 num_classes=vocabSize))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
x = []
y = []

for sentence in sentences:
    sentenceWords = sentence.split(" ")
    sentenceWordsLen = len(sentenceWords)
    for i in range(sentenceWordsLen):
        wordsAfter = sentenceWords[i+1:min(sentenceWordsLen, i+windowSize+1)]
        wordsBefore = sentenceWords[max(0, i-windowSize):i]
        allWords = wordsAfter + wordsBefore
        for word in allWords:
            if word in words:
                if ( (sentenceWords[i] != word) and (sentenceWords[i] in words)):
                    x.append(words.index(sentenceWords[i]))
                    y.append(words.index(word))
                    
for a,b in zip(x,y):
    print(words[a],words[b])
# Out:
# king husband
# husband queen
# husband king
# queen husband
# queen wife
# wife king
# wife queen
# king wife
# king male
# male king
# queen female
# female queen
# king marry
# king queen
# marry queen
# marry king
# queen king
# queen marry

# %%
def getTrainingBatch():
    num = randint(0, len(x) - batchSize - 1)
    arr = x[num:num + batchSize]
    labels = y[num:num + batchSize]
    # batch_data = np.array(batch_data)
    label_data = np.transpose(np.array([labels]))
    return arr,label_data

# %%
trainInputs, trainLabels  = getTrainingBatch()

# %%
valid_examples = [words.index(x) for x in valid_words]
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %%
# Cosine similarity between words
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# Add variable initializer.
init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

# %%
# Run the skip gram model.
loss_vec = []
loss_x_vec = []
for i in range(iterations):
    trainInputs, trainLabels  = getTrainingBatch()
    feed_dict={train_inputs: trainInputs, train_outputs: trainLabels}
   
    # Run the train step
    sess.run(optimizer, feed_dict=feed_dict)

    # Return the loss
    if (i + 1) % debug_iterations == 0:
        loss_val = sess.run(loss, feed_dict=feed_dict)
        loss_vec.append(loss_val)
        loss_x_vec.append(i+1)
        print('\nLoss at step {} : {}'.format(i+1, loss_val))
      
        # Validation: Print some random words and top 5 related words
        sim = sess.run(similarity, feed_dict=feed_dict)
        for j in range(len(valid_words)):
            valid_word = valid_words[j]
            # top_k = number of nearest neighbors
            top_k = 3
            nearest = (-sim[j, :]).argsort()[1:top_k+1]
            log_str = "Nearest to {}:".format(valid_word)
            for k in range(top_k):
                close_word = word_dictionary_rev[nearest[k]]
                log_str = '{} {},'.format(log_str, close_word)
            print(log_str)
# Out:
# Loss at step 200 : 1.346443772315979
# Nearest to king: marry, male, female,
# Nearest to queen: wife, female, male,
#
# Loss at step 400 : 0.9364078044891357
# Nearest to king: marry, male, female,
# Nearest to queen: male, wife, husband,
#
# Loss at step 600 : 2.0917153358459473
# Nearest to king: male, marry, female,
# Nearest to queen: male, husband, female,
#
# Loss at step 800 : 1.0701323747634888
# Nearest to king: male, marry, female,
# Nearest to queen: male, husband, female,
#
# Loss at step 1000 : 1.4059538841247559
# Nearest to king: marry, male, female,
# Nearest to queen: male, female, wife,
#
# Loss at step 1200 : 0.6607356071472168
# Nearest to king: marry, female, queen,
# Nearest to queen: male, female, wife,
#
# Loss at step 1400 : 1.8066346645355225
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 1600 : 1.1467047929763794
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 1800 : 0.9927818775177002
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, female,
#
# Loss at step 2000 : 0.9108092188835144
# Nearest to king: female, queen, husband,
# Nearest to queen: male, husband, king,
#
# Loss at step 2200 : 1.230595350265503
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, king,
#
# Loss at step 2400 : 1.313020944595337
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, king,
#
# Loss at step 2600 : 0.9475106000900269
# Nearest to king: female, queen, wife,
# Nearest to queen: male, marry, husband,
#
# Loss at step 2800 : 1.0459223985671997
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, wife,
#
# Loss at step 3000 : 0.7730573415756226
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, female,
#
# Loss at step 3200 : 0.8624740839004517
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, king,
#
# Loss at step 3400 : 0.9772982001304626
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 3600 : 1.8019092082977295
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, female,
#
# Loss at step 3800 : 0.8145859241485596
# Nearest to king: female, queen, husband,
# Nearest to queen: male, king, female,
#
# Loss at step 4000 : 0.9056709408760071
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 4200 : 0.8355244398117065
# Nearest to king: female, husband, queen,
# Nearest to queen: male, female, king,
#
# Loss at step 4400 : 2.625638484954834
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, wife,
#
# Loss at step 4600 : 1.5976530313491821
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 4800 : 1.4280691146850586
# Nearest to king: female, wife, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 5000 : 1.2556498050689697
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 5200 : 1.658768653869629
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 5400 : 1.3284120559692383
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 5600 : 0.8872012495994568
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, female,
#
# Loss at step 5800 : 0.774451494216919
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 6000 : 1.1366242170333862
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 6200 : 1.9888195991516113
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 6400 : 0.6794203519821167
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 6600 : 1.4270730018615723
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, female,
#
# Loss at step 6800 : 1.098996877670288
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 7000 : 1.3310556411743164
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 7200 : 1.2131162881851196
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 7400 : 0.6905267834663391
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 7600 : 1.0425961017608643
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 7800 : 1.5023164749145508
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 8000 : 1.019562005996704
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 8200 : 0.9424399137496948
# Nearest to king: female, wife, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 8400 : 1.3149359226226807
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 8600 : 1.0807088613510132
# Nearest to king: female, wife, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 8800 : 1.1619579792022705
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, wife,
#
# Loss at step 9000 : 1.1895198822021484
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 9200 : 1.3708033561706543
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 9400 : 1.7181192636489868
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, female,
#
# Loss at step 9600 : 1.8468523025512695
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 9800 : 1.0978589057922363
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 10000 : 1.4648709297180176
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, female,
#
# Loss at step 10200 : 1.4787622690200806
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 10400 : 1.1222108602523804
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, wife,
#
# Loss at step 10600 : 1.5983281135559082
# Nearest to king: female, wife, husband,
# Nearest to queen: male, female, husband,
#
# Loss at step 10800 : 1.3332276344299316
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 11000 : 0.7000184059143066
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, king,
#
# Loss at step 11200 : 1.519906759262085
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 11400 : 1.6097955703735352
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 11600 : 1.6962021589279175
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, wife,
#
# Loss at step 11800 : 0.5963971018791199
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 12000 : 0.9734470844268799
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 12200 : 0.9821135401725769
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 12400 : 1.4849870204925537
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 12600 : 1.084362506866455
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 12800 : 1.1629624366760254
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, wife,
#
# Loss at step 13000 : 0.9679793119430542
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, wife,
#
# Loss at step 13200 : 1.096491813659668
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 13400 : 1.7060502767562866
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 13600 : 0.8110888004302979
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, king,
#
# Loss at step 13800 : 1.0415571928024292
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 14000 : 0.7606209516525269
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 14200 : 1.4379165172576904
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
# Loss at step 14400 : 1.1545634269714355
# Nearest to king: female, queen, husband,
# Nearest to queen: male, king, female,
#
# Loss at step 14600 : 1.2386170625686646
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 14800 : 0.9302080869674683
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, wife,
#
# Loss at step 15000 : 1.826368808746338
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 15200 : 1.3812000751495361
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 15400 : 0.8740431070327759
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 15600 : 1.531395435333252
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 15800 : 0.8150807619094849
# Nearest to king: female, husband, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 16000 : 1.8211631774902344
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, female,
#
# Loss at step 16200 : 1.0057873725891113
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 16400 : 1.6933486461639404
# Nearest to king: female, marry, wife,
# Nearest to queen: male, female, husband,
#
# Loss at step 16600 : 1.4908559322357178
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 16800 : 1.5575878620147705
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, wife,
#
# Loss at step 17000 : 1.6258857250213623
# Nearest to king: female, wife, marry,
# Nearest to queen: male, king, wife,
#
# Loss at step 17200 : 0.9059846997261047
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, female,
#
# Loss at step 17400 : 0.8716743588447571
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, wife,
#
# Loss at step 17600 : 0.6920959949493408
# Nearest to king: female, wife, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 17800 : 0.8085430860519409
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 18000 : 1.2282031774520874
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, wife,
#
# Loss at step 18200 : 1.2840156555175781
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 18400 : 0.7689667344093323
# Nearest to king: female, marry, wife,
# Nearest to queen: male, wife, king,
#
# Loss at step 18600 : 0.8363794088363647
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 18800 : 1.7551276683807373
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 19000 : 0.8543276786804199
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 19200 : 1.399306297302246
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 19400 : 1.5592247247695923
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 19600 : 0.8728232979774475
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 19800 : 1.1738346815109253
# Nearest to king: female, wife, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 20000 : 0.9583834409713745
# Nearest to king: female, husband, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 20200 : 0.9729626774787903
# Nearest to king: female, marry, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 20400 : 0.8552834987640381
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, female,
#
# Loss at step 20600 : 1.2501331567764282
# Nearest to king: female, marry, husband,
# Nearest to queen: male, king, husband,
#
# Loss at step 20800 : 1.2356603145599365
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 21000 : 1.5501302480697632
# Nearest to king: female, wife, marry,
# Nearest to queen: male, marry, husband,
#
# Loss at step 21200 : 0.7541600465774536
# Nearest to king: female, queen, husband,
# Nearest to queen: male, king, female,
#
# Loss at step 21400 : 1.252690315246582
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 21600 : 1.8633852005004883
# Nearest to king: female, queen, husband,
# Nearest to queen: male, king, husband,
#
# Loss at step 21800 : 1.0050771236419678
# Nearest to king: female, marry, husband,
# Nearest to queen: male, husband, wife,
#
# Loss at step 22000 : 0.8685953617095947
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 22200 : 1.2557073831558228
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, female,
#
# Loss at step 22400 : 2.0104730129241943
# Nearest to king: female, queen, wife,
# Nearest to queen: male, king, husband,
#
# Loss at step 22600 : 0.960275411605835
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, marry,
#
# Loss at step 22800 : 1.2007873058319092
# Nearest to king: female, wife, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 23000 : 0.9749195575714111
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, king,
#
# Loss at step 23200 : 0.8836265802383423
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, female,
#
# Loss at step 23400 : 1.1512553691864014
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 23600 : 2.289839267730713
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, king,
#
# Loss at step 23800 : 0.8017038702964783
# Nearest to king: female, husband, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 24000 : 1.1201528310775757
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, king,
#
# Loss at step 24200 : 1.0942388772964478
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 24400 : 1.975043535232544
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 24600 : 1.214583396911621
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, king,
#
# Loss at step 24800 : 1.1957769393920898
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 25000 : 1.2477192878723145
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, wife,
#
# Loss at step 25200 : 1.374572992324829
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, king,
#
# Loss at step 25400 : 1.1710186004638672
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, female,
#
# Loss at step 25600 : 1.7818655967712402
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 25800 : 1.6070241928100586
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 26000 : 0.8007628917694092
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, marry,
#
# Loss at step 26200 : 0.8645561337471008
# Nearest to king: female, marry, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 26400 : 1.5272607803344727
# Nearest to king: female, wife, queen,
# Nearest to queen: male, husband, marry,
#
# Loss at step 26600 : 1.2631690502166748
# Nearest to king: female, wife, queen,
# Nearest to queen: male, king, husband,
#
# Loss at step 26800 : 1.1644622087478638
# Nearest to king: female, wife, husband,
# Nearest to queen: male, husband, marry,
#
# Loss at step 27000 : 1.2580093145370483
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 27200 : 1.1713846921920776
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 27400 : 1.6423300504684448
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 27600 : 1.2017133235931396
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 27800 : 1.7302385568618774
# Nearest to king: female, queen, wife,
# Nearest to queen: male, husband, king,
#
# Loss at step 28000 : 1.0058351755142212
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 28200 : 1.3610917329788208
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, marry,
# Loss at step 28400 : 1.0233253240585327
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 28600 : 1.5426623821258545
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 28800 : 1.2026007175445557
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 29000 : 0.6736055016517639
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 29200 : 1.3125309944152832
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 29400 : 1.1157325506210327
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, king,
#
# Loss at step 29600 : 1.3983553647994995
# Nearest to king: female, wife, queen,
# Nearest to queen: male, king, marry,
#
# Loss at step 29800 : 1.4603530168533325
# Nearest to king: female, marry, wife,
# Nearest to queen: male, wife, husband,
#
# Loss at step 30000 : 1.2816299200057983
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 30200 : 1.2433644533157349
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, female,
#
# Loss at step 30400 : 0.952784538269043
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 30600 : 0.7213749885559082
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 30800 : 0.5678201913833618
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 31000 : 1.4208046197891235
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 31200 : 1.0089812278747559
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 31400 : 1.1434160470962524
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 31600 : 1.1159894466400146
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 31800 : 1.4672796726226807
# Nearest to king: female, marry, husband,
# Nearest to queen: male, husband, wife,
#
# Loss at step 32000 : 0.76161789894104
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 32200 : 1.086125135421753
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 32400 : 1.1807234287261963
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 32600 : 1.3562510013580322
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 32800 : 1.8838239908218384
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, female,
#
# Loss at step 33000 : 1.4682496786117554
# Nearest to king: female, queen, marry,
# Nearest to queen: male, king, husband,
#
# Loss at step 33200 : 1.0267698764801025
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 33400 : 1.873124122619629
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 33600 : 1.2043590545654297
# Nearest to king: female, wife, husband,
# Nearest to queen: male, marry, husband,
#
# Loss at step 33800 : 1.1501901149749756
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 34000 : 0.9616252183914185
# Nearest to king: female, husband, marry,
# Nearest to queen: male, wife, marry,
#
# Loss at step 34200 : 1.195160150527954
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 34400 : 1.040784239768982
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 34600 : 1.4720655679702759
# Nearest to king: female, wife, husband,
# Nearest to queen: male, marry, wife,
#
# Loss at step 34800 : 1.6268869638442993
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 35000 : 0.8297806978225708
# Nearest to king: female, husband, wife,
# Nearest to queen: male, marry, husband,
#
# Loss at step 35200 : 1.0947257280349731
# Nearest to king: female, queen, husband,
# Nearest to queen: male, wife, marry,
#
# Loss at step 35400 : 2.026313066482544
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 35600 : 1.73081636428833
# Nearest to king: female, marry, husband,
# Nearest to queen: male, husband, wife,
#
# Loss at step 35800 : 1.0398300886154175
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 36000 : 0.6473637223243713
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 36200 : 0.6791165471076965
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 36400 : 1.1249693632125854
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 36600 : 0.7539095282554626
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 36800 : 1.6139487028121948
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 37000 : 1.0499985218048096
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 37200 : 1.0495516061782837
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 37400 : 0.9525567293167114
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 37600 : 0.8775029182434082
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 37800 : 1.4608914852142334
# Nearest to king: female, wife, husband,
# Nearest to queen: male, marry, husband,
#
# Loss at step 38000 : 1.7595610618591309
# Nearest to king: female, queen, wife,
# Nearest to queen: male, husband, marry,
#
# Loss at step 38200 : 0.6554470658302307
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 38400 : 1.2310365438461304
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 38600 : 0.8957288265228271
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 38800 : 0.6880909204483032
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 39000 : 1.16941499710083
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 39200 : 0.9459361433982849
# Nearest to king: female, marry, wife,
# Nearest to queen: male, wife, husband,
#
# Loss at step 39400 : 1.5635948181152344
# Nearest to king: female, wife, marry,
# Nearest to queen: male, marry, husband,
#
# Loss at step 39600 : 2.4161720275878906
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 39800 : 1.0156221389770508
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 40000 : 2.010509729385376
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 40200 : 1.5219414234161377
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 40400 : 1.328197956085205
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 40600 : 0.8636157512664795
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 40800 : 1.6786043643951416
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 41000 : 1.2974650859832764
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 41200 : 1.7109272480010986
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 41400 : 1.250432014465332
# Nearest to king: female, wife, husband,
# Nearest to queen: male, husband, marry,
#
# Loss at step 41600 : 1.233201265335083
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 74000 : 0.9671503901481628
# Nearest to king: female, queen, wife,
# Nearest to queen: male, husband, marry,
#
# Loss at step 74200 : 1.2768990993499756
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 74400 : 1.7706325054168701
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 74600 : 0.954187273979187
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 74800 : 1.3436651229858398
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 75000 : 1.7692034244537354
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 75200 : 1.3778307437896729
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 75400 : 1.051296353340149
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 75600 : 0.9828162789344788
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 75800 : 0.8004168272018433
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 76000 : 1.1487419605255127
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 76200 : 1.4329081773757935
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 76400 : 1.0641053915023804
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 76600 : 1.7590237855911255
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 76800 : 1.2145200967788696
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 77000 : 0.8547319173812866
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 77200 : 1.1634435653686523
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 77400 : 0.717362105846405
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 77600 : 0.7936012744903564
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 77800 : 0.6736935377120972
# Nearest to king: female, queen, wife,
# Nearest to queen: male, husband, marry,
#
# Loss at step 78000 : 1.1926932334899902
# Nearest to king: female, wife, husband,
# Nearest to queen: male, marry, husband,
#
# Loss at step 78200 : 1.2137434482574463
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 78400 : 0.9727093577384949
# Nearest to king: female, queen, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 78600 : 0.8623567819595337
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 78800 : 1.0651347637176514
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 79000 : 0.7376384735107422
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 79200 : 1.149871826171875
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 79400 : 1.1197664737701416
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 79600 : 1.225045084953308
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 79800 : 1.1113752126693726
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 80000 : 0.7392480969429016
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 80200 : 1.028132438659668
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 80400 : 1.0145554542541504
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 80600 : 1.868990421295166
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 80800 : 0.949533998966217
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 81000 : 1.0314915180206299
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 81200 : 1.7676992416381836
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 81400 : 0.9361752271652222
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 81600 : 1.1956504583358765
# Nearest to king: female, queen, wife,
# Nearest to queen: male, husband, marry,
#
# Loss at step 81800 : 1.0676045417785645
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 82000 : 1.4808847904205322
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 82200 : 0.7648879289627075
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 82400 : 0.8101413249969482
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 82600 : 1.1836150884628296
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 82800 : 0.7746366262435913
# Nearest to king: female, queen, wife,
# Nearest to queen: male, marry, husband,
#
# Loss at step 83000 : 0.9414523839950562
# Nearest to king: female, queen, marry,
# Nearest to queen: male, wife, husband,
#
# Loss at step 83200 : 1.3767263889312744
# Nearest to king: female, marry, queen,
# Nearest to queen: male, wife, husband,
#
# Loss at step 83400 : 1.201909065246582
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 83600 : 1.5717647075653076
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 83800 : 1.5068167448043823
# Nearest to king: female, marry, husband,
# Nearest to queen: male, wife, husband,
#
# Loss at step 84000 : 1.3829275369644165
# Nearest to king: female, husband, marry,
# Nearest to queen: male, wife, marry,
#
# Loss at step 84200 : 0.7829146385192871
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 84400 : 1.4339548349380493
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 84600 : 0.8519006967544556
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 84800 : 0.8075625896453857
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 85000 : 1.9002680778503418
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
# Loss at step 85200 : 1.9448246955871582
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 85400 : 1.3977744579315186
# Nearest to king: female, marry, queen,
# Nearest to queen: male, husband, wife,
#
# Loss at step 85600 : 0.6800675392150879
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
#
# Loss at step 85800 : 1.1961207389831543
# Nearest to king: female, wife, marry,
# Nearest to queen: male, husband, marry,
#
# Loss at step 86000 : 0.8571227192878723
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 86200 : 1.0401958227157593
# Nearest to king: female, queen, marry,
# Nearest to queen: male, husband, wife,
#
# Loss at step 86400 : 1.1655471324920654
# Nearest to king: female, marry, wife,
# Nearest to queen: male, husband, wife,
